# %%
import duckdb

# %%
con = duckdb.connect("../data/steam_analytics.duckdb")

# %%
con.sql("SHOW TABLES")
# Out:
# ┌─────────┐
# │  name   │
# │ varchar │
# ├─────────┤
# │ games   │
# └─────────┘

# %%
con.sql("SELECT COUNT(*) FROM games")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │           14 │
# └──────────────┘

# %%
con.sql("""
    SELECT appid, name
    FROM games
    ORDER BY appid
""")
# Out:
# ┌────────┬────────────────────────────────┐
# │ appid  │              name              │
# │ int64  │            varchar             │
# ├────────┼────────────────────────────────┤
# │     10 │ Counter-Strike                 │
# │     20 │ Team Fortress Classic          │
# │     30 │ Day of Defeat                  │
# │     40 │ Deathmatch Classic             │
# │     50 │ Half-Life: Opposing Force      │
# │     60 │ Ricochet                       │
# │     70 │ Half-Life                      │
# │     80 │ Counter-Strike: Condition Zero │
# │    130 │ Half-Life: Blue Shift          │
# │    220 │ Half-Life 2                    │
# │    620 │ Portal 2                       │
# │    730 │ Counter-Strike 2               │
# │ 105600 │ Terraria                       │
# │ 413150 │ Stardew Valley                 │
# └────────┴────────────────────────────────┘
#   14 rows                       2 columns
